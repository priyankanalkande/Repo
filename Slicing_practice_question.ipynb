# %%
#first 3 character
s="python"
print(s[:3])
# Out:
# pyt

# %%
#last 2 character
print(s[-2:])
# Out:
# on

# %%
#remove 1st character
print(s[1:])
# Out:
# ython

# %%
#deve
s= "developer"
print(s[0:4])
# Out:
# deve

# %%
#lop
print(s[-5:-2])
# Out:
# lop

# %%
# Everything except last charcter
print(s[0:-1])
# Out:
# develope

# %%
#middle part "scien"
m= "datascience"
print(s[4:-2])
# Out:
# scien

# %%
#first half only
m= "datascience"
size = len(m)//2
print(m[:size])
# Out:
# datas

# %%
#second half
print(m[size:])
# Out:
# cience

# %%
#Every alternate charcter
s= "abcdef"
print(s[::2])
# Out:
# ace

# %%
#File extension
filename="care_delta_income_sepetember_2024.xlsx"
print(filename[-5:])
# Out:
# .xlsx

# %%
#File name without extension
print(filename[0:-5])
# Out:
# care_delta_income_sepetember_2024

# %%
#year only
print(filename[-9:-5])
# Out:
# 2024

# %%
#job completed sucessfully
log="[INFO] job completed sucessfully [END]"
print(log[6:-6])
# Out:
#  job completed sucessfully

# %%
#Reverse full string 
s="machinelearning"
print(s[::-1])
# Out:
# gninraelenihcam

# %%
#Reverse only "learning"
s="machinelearning"
#print(s[-1:-9:-1])
print(s[:-9:-1])
# Out:
# gninrael

# %%
#Reverse string except first charcter
first=s[0]
rev =s[:-15:-1]
print(first+ rev)
# Out:
# mgninraelenihca

# %%
#Charcters from index 3 to 12 skipping 2 
s="ABCDEFGHIJKLMNO"
print(s[3:12:2])
# Out:
# DFHJL

# %%
#Reverse slice from index 10 to 3 
print(s[10:3:-1])
# Out:
# KJIHGFE

# %%
#File Name 
path="/mnt/data/input/care_delta_income_2024.csv"
print(path[16:])
# Out:
# care_delta_income_2024.csv

# %%
#File name without extension
print(path[16:-4])
# Out:
# care_delta_income_2024

# %%
#Extension

# %%
print(path[-4:])
# Out:
# .csv

# %%
# XXXX-XXXX-9012
a="123456789012"
print("XXXX-XXXX-"+a[-4:])
# Out:
# XXXX-XXXX-9012
